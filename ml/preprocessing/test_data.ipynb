# %%
import pandas as pd

# %%
df = pd.read_csv("C:\Imp\g\Traffic Congestion Project\TrafficCongestionPredictor\ml\data\delhi_traffic_features.csv")
df_20 = df.iloc[int(df.shape[0]*0.8):int(df.shape[0])]
print(df_20)
# Out:
#          Trip_ID      start_area         end_area  distance_km   time_of_day  \
# 3200  TRIP_03201    Lajpat Nagar           Dwarka        18.84     Afternoon
# 3201  TRIP_03202  Rajouri Garden  Noida Sector 18        21.63     Afternoon
# 3202  TRIP_03203       Hauz Khas       Karol Bagh        11.44  Evening Peak
# 3203  TRIP_03204       Pitampura    Chandni Chowk        11.29  Evening Peak
# 3204  TRIP_03205          Rohini      IGI Airport        21.91  Morning Peak
# ...          ...             ...              ...          ...           ...
# 3995  TRIP_03996  Rajouri Garden           Dwarka         9.64  Morning Peak
# 3996  TRIP_03997          Rohini           Dwarka        17.53  Morning Peak
# 3997  TRIP_03998     Preet Vihar     Lajpat Nagar         9.58  Morning Peak
# 3998  TRIP_03999      Karol Bagh        Hauz Khas        11.44  Evening Peak
# 3999  TRIP_04000     IGI Airport      Civil Lines        18.43         Night
#
# ...
