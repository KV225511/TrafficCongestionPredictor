# %%
import pandas as pd

# %%
df = pd.read_csv("C:\Imp\g\Traffic Congestion Project\TrafficCongestionPredictor\ml\data\delhi_traffic_features.csv")
df_80 = df.iloc[:int(df.shape[0]*0.8)]
print(df_80)
# Out:
#          Trip_ID       start_area       end_area  distance_km   time_of_day  \
# 0     TRIP_00001      Vasant Kunj        Kalkaji         9.44         Night
# 1     TRIP_00002  Greater Kailash        Kalkaji         2.15         Night
# 2     TRIP_00003        Janakpuri     Model Town        14.54  Morning Peak
# 3     TRIP_00004     Punjabi Bagh         Dwarka        11.86         Night
# 4     TRIP_00005           Rohini  Chandni Chowk        20.26     Afternoon
# ...          ...              ...            ...          ...           ...
# 3195  TRIP_03196          Kalkaji    Mayur Vihar         9.67  Evening Peak
# 3196  TRIP_03197           Rohini  Chandni Chowk        20.26     Afternoon
# 3197  TRIP_03198      Preet Vihar    Civil Lines         7.88     Afternoon
# 3198  TRIP_03199      Preet Vihar     Karol Bagh        10.02  Morning Peak
# 3199  TRIP_03200          Kalkaji          AIIMS         5.39     Afternoon
#
#      day_of_week weather_condition traffic_density_level   road_type  \
# 0        Weekday             Clear                   Low   Main Road
# 1        Weekend             Clear                   Low   Main Road
# 2        Weekday              Rain                  High  Inner Road
# 3        Weekday             Clear                   Low     Highway
# 4        Weekday               Fog                Medium     Highway
# ...          ...               ...                   ...         ...
# 3195     Weekday               Fog                  High   Main Road
# 3196     Weekday              Rain                Medium   Main Road
# 3197     Weekday             Clear                   Low   Main Road
# 3198     Weekend             Clear                Medium     Highway
# 3199     Weekend             Clear                Medium   Main Road
#
#       average_speed_kmph
# 0                   37.8
# 1                   42.7
# 2                    9.7
# 3                   68.5
# 4                   30.3
# ...                  ...
# 3195                15.6
# 3196                24.5
# 3197                48.7
# 3198                66.7
# 3199                27.6
#
# [3200 rows x 10 columns]
